# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import QTable

table = QTable.read('vizier_votable.tsv', format='ascii')
#vmag = table['Vmag']
#bv = table['B-V']

plt.style.use('seaborn')
fig,ax = plt.subplots(1,1)
fig.set_size_inches(10,8)
fig.tight_layout()

ax.set_ylabel("Absolute Magnitude in V")
ax.set_xlabel("B-V Color Index")
ax.set_title("Color Magnitude Diagram for M13")
plt.gca().invert_yaxis()
#ax.plot(bv, (vmag - 5 * (np.log10(7000)-1)), color='#3b4370', marker='o', markersize=3, linestyle='None',);
# Out:
# ---------------------------------------------------------------------------
# InconsistentTableError                    Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\astropy\io\ascii\ui.py in _guess(table, read_kwargs, format, fast_reader)
#     487             reader = get_reader(**read_kwargs)
# --> 488             dat = reader.read(table)
#     489             _read_trace.append({'kwargs': read_kwargs,
#
# ~\Miniconda3\lib\site-packages\astropy\io\ascii\core.py in read(self, table)
#    1193
# -> 1194                     raise InconsistentTableError(errmsg)
#    1195
#
# InconsistentTableError: Number of header columns (3) inconsistent with data columns (2) at data line 1
# Header values: ['<?xml', 'version="1.0"', 'encoding="UTF-8"?>']
# Data values: ['xmlns="http://www.ivoa.net/xml/VOTable/v1.2"', '>']
#
# During handling of the above exception, another exception occurred:
#
# InconsistentTableError                    Traceback (most recent call last)
# ...
